# %%
import gymnasium as gym

env = gym.make("CartPole-v1")
print(f"Action space: {env.action_space}")
print(f"Observation space: {env.observation_space}")

# 1. Initialize
obs, info = env.reset() # Notice the new reset return pattern
done = False
total_reward = 0
# 2. The Loop
while not done:
    # This line triggers the actual window update in "human" mode
    env.render() 
    
    action = env.action_space.sample()
    obs, rew, terminated, truncated, info = env.step(action)
    
    # Logic for stopping the loop
    done = terminated or truncated
    
    print(f"{obs} -> {rew}")
    total_reward += rew
print(f"Total reward: {total_reward}")
# 3. The Cleanup (Outside the loop!)
env.close()
print("Environment closed successfully.")
# Out:
# Action space: Discrete(2)
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# [-0.03851916 -0.2198431  -0.03206399  0.24503449] -> 1.0
# [-0.04291601 -0.02427821 -0.0271633  -0.05758727] -> 1.0
# [-0.04340158  0.17122246 -0.02831504 -0.35871515] -> 1.0
# [-0.03997713 -0.02348575 -0.03548935 -0.07509338] -> 1.0
# [-0.04044684 -0.21808143 -0.03699121  0.20618466] -> 1.0
# [-0.04480847 -0.4126554  -0.03286752  0.48697305] -> 1.0
# [-0.05306158 -0.60729855 -0.02312806  0.7691188 ] -> 1.0
# [-0.06520756 -0.41186604 -0.00774569  0.46924934] -> 1.0
# [-0.07344487 -0.21663553  0.0016393   0.17413513] -> 1.0
# [-0.07777759 -0.02153707  0.005122   -0.1180302 ] -> 1.0
# [-0.07820833  0.17351112  0.0027614  -0.40909278] -> 1.0
# [-0.07473811  0.3685938  -0.00542046 -0.70090383] -> 1.0
# [-0.06736623  0.17354742 -0.01943853 -0.40993217] -> 1.0
# [-0.06389528  0.3689395  -0.02763718 -0.70867944] -> 1.0
# [-0.05651649  0.17421103 -0.04181077 -0.42482263] -> 1.0
# [-0.05303227 -0.02029449 -0.05030722 -0.14560811] -> 1.0
# [-0.05343816 -0.21466126 -0.05321938  0.1307891 ] -> 1.0
# [-0.05773139 -0.01881894 -0.0506036  -0.17819758] -> 1.0
# [-0.05810776  0.17698929 -0.05416755 -0.48640504] -> 1.0
# [-0.05456798 -0.01732817 -0.06389565 -0.21127385] -> 1.0
# [-0.05491454  0.1786464  -0.06812113 -0.52340835] -> 1.0
# [-0.05134161  0.37465766 -0.0785893  -0.83675545] -> 1.0
# [-0.04384846  0.57075995 -0.0953244  -1.1530825 ] -> 1.0
# [-0.03243326  0.37700182 -0.11838605 -0.8917477 ] -> 1.0
# [-0.02489322  0.57351357 -0.136221   -1.2191763 ] -> 1.0
# [-0.01342295  0.38038483 -0.16060454 -0.9720921 ] -> 1.0
# [-0.00581526  0.5772549  -0.18004638 -1.3106118 ] -> 1.0
# [ 0.00572984  0.77414143 -0.20625861 -1.6538159 ] -> 1.0
# [ 0.02121267  0.9709877  -0.23933493 -2.0030377 ] -> 1.0
# Total reward: 29.0
# Environment closed successfully.
